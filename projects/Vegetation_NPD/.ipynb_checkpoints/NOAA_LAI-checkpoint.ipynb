# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
from pyhdf.SD import SD, SDC

# %%
ds1 = xr.open_dataset('ESA_satellite/LAI_1999-2020_V2.0.1.nc_LAI_reg_arctic.nc')
ds2 = xr.open_dataset('ESA_satellite/NDVI_1999-2020_GLOBE_PROBAV_V3.0.1.nc_NDVI_reg_arctic.nc')

# %%
ds3 = xr.open_dataset('ESA_satellite/output_file.nc')

# %%
ds4 = xr.open_dataset('ESA_satellite/MOD13C1.A2009161.061.2021135224526.hdf', engine = 'netcdf4')

# %%
ds5 = xr.open_dataset('ESA_satellite/AVHRR-Land_v005_AVH15C1_NOAA-09_19880108_c20180831215230_reg_arctic.nc')

# %%
ds5
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lon: 360, lat: 30)
# Coordinates:
#   * time     (time) datetime64[ns] 1988-01-08
#   * lon      (lon) float64 -180.0 -179.0 -178.0 -177.0 ... 177.0 178.0 179.0
#   * lat      (lat) float64 60.5 61.5 62.5 63.5 64.5 ... 85.5 86.5 87.5 88.5 89.5
# Data variables:
#     LAI      (time, lat, lon) float32 ...
#     FAPAR    (time, lat, lon) float32 ...
#     QA       (time, lat, lon) uint16 ...
# Attributes: (12/44)
#     CDI:                       Climate Data Interface version 2.3.0 (https://...
#     Conventions:               CF-1.6, ACDD-1.3
#     source:                    v45_MODISWV_L3_GEOG_0.05DEG_008-008_88.NOAA-09...
#     institution:               NASA/GSFC/SED/ESD/HBSL/TIS/MODIS-LAND > MODIS ...
#     title:                     Leaf Area and Fraction of Absorbed Photosynthe...
#     keywords:                  EARTH SCIENCE > BIOSPHERE > VEGETATION > VEGET...
#     ...                        ...
# ...

# %%
ds5.LAI.plot()

# %%
hdf = SD('ESA_satellite/MOD13C1.A2009161.061.2021135224526.hdf', SDC.READ)

# %%
hdf.datasets()
# Out:
# {'CMG 0.05 Deg 16 days NDVI': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
#   22,
#   0),
#  'CMG 0.05 Deg 16 days EVI': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
#   22,
#   1),
#  'CMG 0.05 Deg 16 days VI Quality': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
#   23,
#   2),
#  'CMG 0.05 Deg 16 days red reflectance': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
#   22,
#   3),
#  'CMG 0.05 Deg 16 days NIR reflectance': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
#   22,
#   4),
#  'CMG 0.05 Deg 16 days blue reflectance': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
#   22,
#   5),
#  'CMG 0.05 Deg 16 days MIR reflectance': (('YDim:MODIS_Grid_16Day_VI_CMG',
#    'XDim:MODIS_Grid_16Day_VI_CMG'),
#   (3600, 7200),
# ...

# %%
data3D = hdf.select('CMG 0.05 Deg 16 days NDVI')

# %%
data3D

# %%
plt.pcolormesh(data3D)
plt.colorbar()

# %%
lat = hdf.select()
#latitude = lat[:,:]
#lon = hdf.select('XDim:MODIS_Grid_16Day_VI_CMG')
#longitude = lon[:,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 lat = hdf.select()
#       2 #latitude = lat[:,:]
#       3 #lon = hdf.select('XDim:MODIS_Grid_16Day_VI_CMG')
#       4 #longitude = lon[:,:]
#
# TypeError: SD.select() missing 1 required positional argument: 'name_or_index'

# %%
ds3
# Out:
# <xarray.Dataset>
# Dimensions:                                   (dim_0: 3600, dim_1: 7200)
# Dimensions without coordinates: dim_0, dim_1
# Data variables: (12/13)
#     CMG 0.05 Deg 16 days NDVI                 (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days EVI                  (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days VI Quality           (dim_0, dim_1) uint16 ...
#     CMG 0.05 Deg 16 days red reflectance      (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days NIR reflectance      (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days blue reflectance     (dim_0, dim_1) int16 ...
#     ...                                        ...
#     CMG 0.05 Deg 16 days Avg sun zen angle    (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days NDVI std dev         (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days EVI std dev          (dim_0, dim_1) int16 ...
#     CMG 0.05 Deg 16 days #1km pix used        (dim_0, dim_1) uint8 ...
# ...

# %%
ds4
# Out:
# <xarray.Dataset>
# Dimensions:                                   (
#                                                YDim:MODIS_Grid_16Day_VI_CMG: 3600,
#                                                XDim:MODIS_Grid_16Day_VI_CMG: 7200)
# Dimensions without coordinates: YDim:MODIS_Grid_16Day_VI_CMG,
#                                 XDim:MODIS_Grid_16Day_VI_CMG
# Data variables: (12/13)
#     CMG 0.05 Deg 16 days NDVI                 (YDim:MODIS_Grid_16Day_VI_CMG, XDim:MODIS_Grid_16Day_VI_CMG) float32 ...
#     CMG 0.05 Deg 16 days EVI                  (YDim:MODIS_Grid_16Day_VI_CMG, XDim:MODIS_Grid_16Day_VI_CMG) float32 ...
#     CMG 0.05 Deg 16 days VI Quality           (YDim:MODIS_Grid_16Day_VI_CMG, XDim:MODIS_Grid_16Day_VI_CMG) float32 ...
#     CMG 0.05 Deg 16 days red reflectance      (YDim:MODIS_Grid_16Day_VI_CMG, XDim:MODIS_Grid_16Day_VI_CMG) float32 ...
#     CMG 0.05 Deg 16 days NIR reflectance      (YDim:MODIS_Grid_16Day_VI_CMG, XDim:MODIS_Grid_16Day_VI_CMG) float32 ...
# ...

# %%
ds3['CMG 0.05 Deg 16 days NDVI'].plot()

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 768, lon: 360, lat: 30)
# Coordinates:
#   * time     (time) datetime64[ns] 1999-01-10 1999-01-20 ... 2020-04-30
#   * lon      (lon) float64 -180.0 -179.0 -178.0 -177.0 ... 177.0 178.0 179.0
#   * lat      (lat) float64 60.5 61.5 62.5 63.5 64.5 ... 85.5 86.5 87.5 88.5 89.5
# Data variables:
#     LAI      (time, lat, lon) float32 ...
# Attributes: (12/21)
#     CDI:                  Climate Data Interface version 2.4.0 (https://mpime...
#     Conventions:          CF-1.6
#     source:               Derived from EO satellite imagery
#     institution:          VITO NV
#     product_version:      V2.0.2
#     long_name:            Leaf Area Index
#     ...                   ...
#     parent_identifier:    urn:cgls:global:lai_v2_1km
#     time_coverage_end:    1999-03-20T23:59:59Z
#     title:                10-daily Leaf Area Index 1KM: GLOBE 1999-01-10T00:0...
#     identifier:           urn:cgls:global:lai_v2_1km:LAI_199901100000_GLOBE_V...
# ...

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 774, lon: 360, lat: 30)
# Coordinates:
#   * time     (time) datetime64[ns] 1999-01-01 1999-01-11 ... 2020-06-21
#   * lon      (lon) float64 -180.0 -179.0 -178.0 -177.0 ... 177.0 178.0 179.0
#   * lat      (lat) float64 60.5 61.5 62.5 63.5 64.5 ... 85.5 86.5 87.5 88.5 89.5
# Data variables:
#     NDVI     (time, lat, lon) float32 ...
# Attributes: (12/21)
#     CDI:                  Climate Data Interface version 2.4.0 (https://mpime...
#     Conventions:          CF-1.6
#     source:               Derived from EO satellite imagery
#     institution:          VITO NV
#     processing_level:     L3
#     identifier:           urn:cgls:global:ndvi_v3_1km:NDVI_199901010000_GLOBE...
#     ...                   ...
#     platform:             SPOT-4
#     title:                10-daily Normalized Difference Vegetation Index 1KM...
#     archive_facility:     VITO
#     parent_identifier:    urn:cgls:global:ndvi_v3_1km
# ...

# %%
ds1.sel(time = ds1.time.dt.year == 2014).LAI.mean('time').plot()

# %%
ds1.sel(time = ds1.time.dt.year == 2013).LAI.mean('time').plot()

# %%
ds2.sel(time = ds2.time.dt.year == 2014).NDVI.mean('time').plot()

# %%
ds2.sel(time = ds2.time.dt.year == 2015).NDVI.mean('time').plot()

# %%
ds2.sel(time = ds2.time.dt.year == 2016).NDVI.mean('time').plot()

# %%
ds2.sel(time = ds2.time.dt.year == 2013).NDVI.mean('time').plot()

# %%
ds2.sel(time = ds2.time.dt.year == 2016).where(ds2.sel(time = ds2.time.dt.year == 2013).NDVI.std('time') > 0).NDVI.mean('time').plot()

# %%
ds1 = ds1.where(ds1.sel(time = ds1.time.dt.year == 2013).std('time') > 0)

# %%
ds2 = ds2.where(ds2.sel(time = ds2.time.dt.year == 2013).std('time') > 0)

# %%
ds2.sel(time = ds2.time.dt.year == 2016).NDVI.mean('time').plot()

# %%
ds2.sel(time = ds2.time.dt.year == 2013).NDVI.mean('time').plot()

# %%
(ds2.sel(time = ds2.time.dt.year == 2016).NDVI.mean('time') - ds2.sel(time = ds2.time.dt.year == 2013).NDVI.mean('time')).plot(cmap = 'viridis')

# %%
ds1.sel(time = ds1.time.dt.year == 2016).LAI.mean('time').plot()

# %%
ds1.sel(time = ds1.time.dt.year == 2013).LAI.mean('time').plot()

# %%
(ds1.sel(time = ds1.time.dt.year == 2016).LAI.mean('time') - ds1.sel(time = ds1.time.dt.year == 2013).LAI.mean('time')).plot(cmap = 'viridis')
