# %%
library(rWind)  
library(raster)  
library(rworldmap)  
library(shape)
library(gdistance)
library(RColorBrewer)
library(rgdal)
library(ncdf4) # package for netcdf manipulation
# Out:
# Loading required package: sp
#
# ### Welcome to rworldmap ###
#
# For a short introduction type : 	 vignette('rworldmap')
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:raster’:
#
#     union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘gdistance’
#
#
# The following object is masked from ‘package:igraph’:
#
#     normalize
#
#
# Warning message:
# “package ‘RColorBrewer’ was built under R version 4.1.2”
# Warning message:
# “package ‘rgdal’ was built under R version 4.1.2”
# Please note that rgdal will be retired by the end of 2023,
# plan transition to sf/stars/terra functions using GDAL and PROJ
# at your earliest convenience.
#
# rgdal: version: 1.5-30, (SVN revision 1171)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 3.4.2, released 2022/03/08
# Path to GDAL shared files: /Library/Frameworks/R.framework/Versions/4.1/Resources/library/rgdal/gdal
# GDAL binary built with GEOS: FALSE
# Loaded PROJ runtime: Rel. 8.2.1, January 1st, 2022, [PJ_VERSION: 821]
# Path to PROJ shared files: /Users/nomikosskyllas/anaconda3/share/proj
# PROJ CDN enabled: TRUE
# Linking to sp version:1.4-6
# To mute warnings of possible GDAL/OSR exportToProj4() degradation,
# use options("rgdal_show_exportToProj4_warnings"="none") before loading sp or rgdal.

# %%
my_wind_data <- read.csv('springMeanSpeed.csv')

# %%
my_wind_data <- my_wind_data[c('lat', 'lon', 'dir', 'speed')]

# %%
my_raster <- wind2raster(my_wind_data)

# %%
chla_data <- read.csv('chlSpring.csv')

# %%
chla_data <- chla_data[c('lon', 'lat', 'chlor_a')]

# %%
chla <- rasterFromXYZ(chla_data)

# %%
bird_SS_data <- read.csv('../Maarten_project/nomi_data/gdf_SS_mean.csv')

# %%
bird_NS_data <- read.csv('../Maarten_project/nomi_data/gdf_NS_mean.csv')

# %% [markdown]
# ## My model with 4 components: Support, distance, food, crosswinds

# %%
log_chla <- as.matrix(log10(chla))

# %%
# My formula
myCost05_map <- function(wind.direction, wind.speed, target, type = "active", chla = chla$chlor_a, alpha, beta, gamma, delta) {
  
  ###################  
  # 1) Preprocessing:
  ###################
    
  # The difference between the wind direction and the bid's PDM
  dif <- abs(wind.direction - target)
  
  # Convert wind support to cost: Low wind support -> high cost, high wind support -> low cost
  # Method: 1) Subtract the 99th percentile from wind support values: Low support rasters now have large negative values, high support rasters are 
  # close to 0. 2) Take their absolute values: Low support rasters have now high positive values (high cost), high-support rasters are still close to 0
  # (low cost)
  costx <- abs(wind.speed[!is.na(dif)] * cos(dif[!is.na(dif)] * pi/180) - quantile(wind.speed[!is.na(dif)] * cos(dif[!is.na(dif)] * pi/180), 0.99))
  #costx <- abs(wind.speed * cos(dif * pi/180) - quantile(wind.speed * cos(dif * pi/180), 0.99, na.rm = TRUE))

  # Chla is hevily sqewed: Many zeros and a few high values. I take its logarithm, and rasters with > -0.5 (high chl a concentration) all get a 
  # (minimum) value of -0.5. Later on, in the actual formula (next step) I add 0.5 and take its absolute (like I did with support). Low-chl rasters
  # have high positive values (cost) while productive rasters are close to 0.
  log_chla <- as.matrix(log10(chla[!is.na(dif)]))
  log_chla[log_chla > -0.5] <- -0.5
  log_chla[is.na(log_chla)] <- 0
  
  raster_dist <- raster(matrix(6, 180, 360),
             xmn = -180.5, xmx = 179.5,
             ymn = -90, ymx = 90, crs=CRS("+proj=longlat +datum=WGS84 +no_defs"))
    
     
  ################################  
  # 2) The 4 formulas (components)
  ################################
    
  # Each coefficient takes a value between 0 and 1. Their sum has to be always = 1.
  a <- alpha     # Wind support
  b <- beta      # Distance
  c <- gamma     # Food
  d <- delta     # Crosswind
    
  # The actual formulas: a) Support is already pre-processed. b) For distance, I take the median value of support. All rasters are eual, so if a bird 
  # wants to follow the shortest great circle distance, it will follow a straight path with a b coefficient = 1. c) I "flip" the log-transformed chl a as
  # explained in the previous step. d) Crosswind component. If a bird wants to follow a path with low crosswinds (usually close to the coast), then a 
  # large d coefficient is necessary.
  dif[!is.na(dif)] <-  a * costx + 
                      # b * raster_dist[!is.na(raster_dist)] #+
                       b * (wind.speed[!is.na(dif)] * 0 + 6) +
                       c * 12 * abs(log_chla + 0.5) +
                       d * abs(wind.speed[!is.na(dif)] * sin(dif[!is.na(dif)] * pi/180))
    
  # Land rasters have a cost of 1000000. Arctic terns should not fly over land (in reality they do fly shortly over the UK, as far as I know).  
#  dif[is.na(dif)] <- 1000000
  dif[is.na(dif)] <- 0

  dif  
}

# %%
# My formula
myCost05 <- function(wind.direction, wind.speed, target, type = "active", chla = chla$chlor_a, alpha, beta, gamma, delta) {
  
  ###################  
  # 1) Preprocessing:
  ###################
    
  # The difference between the wind direction and the bid's PDM
  dif <- abs(wind.direction - target)
  
  # Convert wind support to cost: Low wind support -> high cost, high wind support -> low cost
  # Method: 1) Subtract the 99th percentile from wind support values: Low support rasters now have large negative values, high support rasters are 
  # close to 0. 2) Take their absolute values: Low support rasters have now high positive values (high cost), high-support rasters are still close to 0
  # (low cost)
  costx <- abs(wind.speed[!is.na(dif)] * cos(dif[!is.na(dif)] * pi/180) - quantile(wind.speed[!is.na(dif)] * cos(dif[!is.na(dif)] * pi/180), 0.99))
  #costx <- abs(wind.speed * cos(dif * pi/180) - quantile(wind.speed * cos(dif * pi/180), 0.99, na.rm = TRUE))
  
  # Chla is hevily sqewed: Many zeros and a few high values. I take its logarithm, and rasters with > -0.5 (high chl a concentration) all get a 
  # (minimum) value of -0.5. Later on, in the actual formula (next step) I add 0.5 and take its absolute (like I did with support). Low-chl rasters
  # have high positive values (cost) while productive rasters are close to 0.
  log_chla <- as.matrix(log10(chla[!is.na(dif)]))
  log_chla[log_chla > -0.5] <- -0.5
  log_chla[is.na(log_chla)] <- 0
  
  weights <- cos(seq(-90, 89) * pi / 180)
  weighted_lat <- raster(matrix(rep(weights, 360),
         ncol = 360, byrow = F), xmn=-180.5, xmx=179.5, ymn=-90, ymx=90, crs = "+proj=longlat +datum=WGS84 +no_defs")
  #raster_dist <- weighted_lat[!is.na(dif)] * wind.speed[!is.na(dif)]
    
  ################################  
  # 2) The 4 formulas (components)
  ################################
    
  # Each coefficient takes a value between 0 and 1. Their sum has to be always = 1.
  a <- alpha     # Wind support
  b <- beta      # Distance
  c <- gamma     # Food
  d <- delta     # Crosswind
    
  # The actual formulas: a) Support is already pre-processed. b) For distance, I take the median value of support. All rasters are eual, so if a bird 
  # wants to follow the shortest great circle distance, it will follow a straight path with a b coefficient = 1. c) I "flip" the log-transformed chl a as
  # explained in the previous step. d) Crosswind component. If a bird wants to follow a path with low crosswinds (usually close to the coast), then a 
  # large d coefficient is necessary.
  dif[!is.na(dif)] <-  (a * costx) + 
                       #b * raster_dist[!is.na(raster_dist)] #+
                       (b * (wind.speed[!is.na(dif)] * 0 + 6)) +
                       (c * 12 * abs(log_chla[!is.na(dif)] + 0.5)) +
                       (d * abs(wind.speed[!is.na(dif)] * sin(dif[!is.na(dif)] * pi/180)))
    
  # Land rasters have a cost of 1000000. Arctic terns should not fly over land (in reality they do fly shortly over the UK, as far as I know).  
  dif[is.na(dif)] <- 1000000
#  dif[is.na(dif)] <- 0

  dif  
}

# %%
# List of coefficients
s = 0
coefflist = c()
for (a in seq(0, 1, 0.1))
{
    for (b in seq(0, 1, 0.1))
    {
        for (c in seq(0, 0.5, 0.1))
        {
            for (d in seq(0, 0, 0.1))
            {if (a + b + c + d == 1)
                {s = s + 1
                coefflist = c(coefflist, c(a, b, c, d))}
            }
        }
    }    
}
s
# Out:
# [1] 47

# %%
# List of all conductance surfaces
mylist <- c()
for (a in seq(0, 1, 0.1))
{
    for (b in seq(0, 1, 0.1))
    {
        for (c in seq(0, 0.5, 0.1))
        {
            for (d in seq(0, 0, 0.1))
            {if (a + b + c + d == 1)
                {mylist <- c(mylist, flow.dispersion(my_raster, fun = myCost05, output = "transitionLayer", type = "active", chla = chla$chlor_a, a, b, c, d))}
            }
        }
    }    
}
# Out:
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# ...
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in (a * costx) + (b * (wind.speed[!is.na(dif)] * 0 + 6)) + (c * :
# “longer object length is not a multiple of shorter object length”
# Warning message in dif[!is.na(dif)] <- (a * costx) + (b * (wind.speed[!is.na(dif)] * :
# “number of items to replace is not a multiple of replacement length”

# %%
mylistC <- c()
for (surf in mylist)
    {
    mylistC <- c(mylistC, geoCorrection(surf))
    }

# %%
A <- c(-25, -73) 
B <- c(-20, 65)
costlist <- c()
for (s in mylist)
    {
    costlist <- c(costlist, costDistance(s, A, B))
    }

# %%
A <- c(-25, -73) 
B <- c(-20, 65)
costlistC <- c()
for (s in mylistC)
    {
    costlistC <- c(costlistC, costDistance(s, A, B))
    }

# %%
options(repr.plot.width = 6, repr.plot.height = 6)
boxplot(costlist)
# Out:
# plot without title

# %%
options(repr.plot.width = 6, repr.plot.height = 6)
boxplot(costlistC)
# Out:
# plot without title

# %%
# List of shortest paths (SpatialLines) for Svalbard birds
A <- c(-25, -73) 
B <- c(-20, 65)
SSlist <- c()
for (m in mylist)
    {SSlist <- c(SSlist, shortestPath(m, A, B, output = "SpatialLines") )
    }

# %%
# List of shortest paths (SpatialLines) for Dutch birds
A <- c(0, -73) 
B <- c(0, 55)
NSlist <- c()
for (m in mylist)
    {NSlist <- c(NSlist, shortestPath(m, A, B, output = "SpatialLines") )
    }

# %%
# List of shortest paths (SpatialLines) for Svalbard birds
A <- c(-25, -73) 
B <- c(-20, 65)
SSlistC <- c()
for (m in mylistC)
    {SSlistC <- c(SSlistC, shortestPath(m, A, B, output = "SpatialLines") )
    }

# %%
# List of shortest paths (SpatialLines) for Dutch birds
A <- c(0, -73) 
B <- c(0, 55)
NSlistC <- c()
for (m in mylistC)
    {NSlistC <- c(NSlistC, shortestPath(m, A, B, output = "SpatialLines") )
    }

# %%
# Plot shortest paths (SpatialLines) for Svalbard birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="Svalbard spring", col = hcl.colors(20)) 
lines(bird_SS_data$lon, bird_SS_data$lat, col = 'black', lwd = 10)
for (m in SSlist)
    {lines(m, col = 'white')
    }
# Out:
# Plot with title “Svalbard spring”

# %%
# Plot shortest paths (SpatialLines) for Svalbard birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="Svalbard spring", col = hcl.colors(20)) 
lines(bird_SS_data$lon, bird_SS_data$lat, col = 'black', lwd = 10)
for (m in SSlistC)
    {lines(m, col = 'white')
    }
# Out:
# Plot with title “Svalbard spring”

# %%
# Plot shortest paths (SpatialLines) for Dutch birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="NL spring", col = hcl.colors(20)) 
lines(bird_NS_data$lon, bird_NS_data$lat, col = 'black', lwd = 10)
for (m in NSlist)
    {lines(m, col = 'white')
    }
# Out:
# Plot with title “NL spring”

# %%
# Plot shortest paths (SpatialLines) for Dutch birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="NL spring", col = hcl.colors(20)) 
lines(bird_NS_data$lon, bird_NS_data$lat, col = 'black', lwd = 10)
for (m in NSlistC)
    {lines(m, col = 'white')
    }
# Out:
# Plot with title “NL spring”

# %% [markdown]
# ## Time for statistics: find the best paths

# %%
library(sp)
library(geosphere)
library(rgeos)
# Out:
# Warning message:
# “package ‘geosphere’ was built under R version 4.1.2”
# rgeos version: 0.5-9, (SVN revision 684)
#  GEOS runtime version: 3.8.1-CAPI-1.13.3
#  Please note that rgeos will be retired by the end of 2023,
# plan transition to sf functions using GEOS at your earliest convenience.
#  Linking to sp version: 1.4-6
#  Polygon checking: TRUE

# %% [markdown]
# ### Non-corrected

# %%
# Extract coordinates from SpatialLines
SScoordlist <- c()
for (i in SSlistC)
{
  SScoordlist <- c(SScoordlist, coordinates(i))
}

# %%
# Extract coordinates from SpatialLines
NScoordlist <- c()
for (i in NSlistC)
{
  NScoordlist <- c(NScoordlist, coordinates(i))
}

# %%
# Take the mean (estimated by my model) lon per degree of lat 
SScoordmeanlist <- list()
for (i in seq(1, length(coefflist)/4, 1))
{
  SScoordmeanlist[[i]] <- as.data.frame(aggregate(x ~ y, geom(SSlistC[[i]]), mean))
}

# %%
# Take the mean (estimated by my model) lon per degree of lat 
NScoordmeanlist <- list()
for (i in seq(1, length(coefflist)/4, 1))
{
  NScoordmeanlist[[i]] <- as.data.frame(aggregate(x ~ y, geom(NSlistC[[i]]), mean))
}

# %%
# Add an extra column: 3-degree bins
SScoordmeanlist3 <- list()
for (i in seq(1, length(coefflist)/4, 1))
    {
        SScoordmeanlist[[i]]['lat_bins3'] <- apply(SScoordmeanlist[[i]]['y'], 2, cut, seq(-79, 80, 3)) 
    }

# %%
# Add an extra column: 3-degree bins
NScoordmeanlist3 <- list()
for (i in seq(1, length(coefflist)/4, 1))
    {
        NScoordmeanlist[[i]]['lat_bins3'] <- apply(NScoordmeanlist[[i]]['y'], 2, cut, seq(-79, 80, 3)) 
    }

# %%
# Average the calculated lon per 3-degree bin
SScoordbins3 <- list()
for (i in seq(1, length(coefflist)/4, 1))
{
  SScoordbins3[[i]] <- as.data.frame(aggregate(x ~ lat_bins3, SScoordmeanlist[[i]], mean))
}

# %%
# Average the calculated lon per 3-degree bin
NScoordbins3 <- list()
for (i in seq(1, length(coefflist)/4, 1))
{
  NScoordbins3[[i]] <- as.data.frame(aggregate(x ~ lat_bins3, NScoordmeanlist[[i]], mean))
}

# %%
# Change the bin labels of the observations (geolocators -> averaged per 3 degrees)
bird_SS_data$lat_bins <- (apply(bird_SS_data['lat_bins'], 2, FUN = function (x) gsub(" ", "", x, fixed = TRUE)))

# %%
# Change the bin labels of the observations (geolocators -> averaged per 3 degrees)
bird_NS_data$lat_bins <- (apply(bird_NS_data['lat_bins'], 2, FUN = function (x) gsub(" ", "", x, fixed = TRUE)))

# %%
# Rename columns to match the model output
colnames(bird_SS_data) <- c('lat_bins3', 'lon', 'lat', 'geometry')

# %%
# Rename columns to match the model output
colnames(bird_NS_data) <- c('lat_bins3', 'lon', 'lat', 'geometry')

# %%
# Merge observations and model by 3-degree bin column
SScoordmerged <- list()
for (i in seq(1, length(coefflist)/4, 1))
{
  SScoordmerged[[i]] <-  merge(bird_SS_data, SScoordbins3[[i]])
}

# %%
# Merge observations and model by 3-degree bin column
NScoordmerged <- list()
for (i in seq(1, length(coefflist)/4, 1))
{
  NScoordmerged[[i]] <-  merge(bird_NS_data, NScoordbins3[[i]])
}

# %%
# Keep only the necessary columns
for (i in seq(1, length(coefflist)/4, 1))
{
  SScoordmerged[[i]] <-  SScoordmerged[[i]][c('lat', 'lon', 'x')]
}

# %%
# Keep only the necessary columns
for (i in seq(1, length(coefflist)/4, 1))
{
  NScoordmerged[[i]] <-  NScoordmerged[[i]][c('lat', 'lon', 'x')]
}

# %%
# Order using lat
for (i in seq(1, length(coefflist)/4, 1))
{
  SScoordmerged[[i]] <-  SScoordmerged[[i]][order(SScoordmerged[[i]]['lat']),]
}
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”

# %%
# Order using lat
for (i in seq(1, length(coefflist)/4, 1))
{
  NScoordmerged[[i]] <-  NScoordmerged[[i]][order(NScoordmerged[[i]]['lat']),]
}
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”

# %%
#coord_merged <- coord_merged[order(coord_merged['lat']),]

# %%
# Create 4 vectors with the 4 coefficients
alpha <- coefflist[seq(1, length(coefflist), 4)]
beta <- coefflist[seq(2, length(coefflist), 4)]
gamma <- coefflist[seq(3, length(coefflist), 4)]
delta <- coefflist[seq(4, length(coefflist), 4)]

# %%
# Calculate statistics (RMSE, SD, corr. coeff) for each simulated shortest path
RMSE <- c()
R <- c()
SD_diff <- c()

for (i in seq(1, length(coefflist)/4, 1))
{
    RMSE <- c(RMSE, sqrt(mean((SScoordmerged[[i]]$x - SScoordmerged[[i]]$lon)**2)))
    R <- c(R, cor(SScoordmerged[[i]]$x, SScoordmerged[[i]]$lon))
    SD_diff <- c(SD_diff, abs(sd(SScoordmerged[[i]]$x) - sd(SScoordmerged[[i]]$lon)))
}
df_SS <- data.frame(a = alpha, b = beta, c = gamma, d = delta, rmse = RMSE, r = R, sd_diff = SD_diff)

# %%
# Remove NAs for the Dutch dataset
for (i in seq(1, length(coefflist)/4, 1))
{
  NScoordmerged[[i]] <-  NScoordmerged[[i]][complete.cases(NScoordmerged[[i]]), ]
}

# %%
# Calculate statistics (RMSE, SD, corr. coeff) for each simulated shortest path
RMSE <- c()
R <- c()
SD_diff <- c()

for (i in seq(1, length(coefflist)/4, 1))
{
    RMSE <- c(RMSE, sqrt(mean((NScoordmerged[[i]]$x - NScoordmerged[[i]]$lon)**2)))
    R <- c(R, cor(NScoordmerged[[i]]$x, NScoordmerged[[i]]$lon))
    SD_diff <- c(SD_diff, abs(sd(NScoordmerged[[i]]$x) - sd(NScoordmerged[[i]]$lon)))
}
df_NS <- data.frame(a = alpha, b = beta, c = gamma, d = delta, rmse = RMSE, r = R, sd_diff = SD_diff)

# %% [markdown]
# ## Svalbard birds

# %%
head(df_SS[order(df_SS['rmse']),], 25)
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
#    a   b   c   d rmse      r         sd_diff
# 43 0.8 0.1 0.1 0  6.583511 0.9436364 0.2689059
# 40 0.7 0.1 0.2 0  6.619247 0.9426738 0.3756095
# 42 0.8 0.0 0.2 0  6.623152 0.9431495 0.3273424
# 37 0.6 0.2 0.2 0  6.638281 0.9425259 0.4259850
# 34 0.5 0.5 0.0 0  6.710797 0.9417644 0.8290164
# 45 0.9 0.0 0.1 0  6.840539 0.9344757 1.7247763
# 38 0.6 0.4 0.0 0  6.877161 0.9431868 0.6839203
# 41 0.7 0.3 0.0 0  6.915435 0.9389956 0.2045182
# 44 0.8 0.2 0.0 0  6.967883 0.9371907 0.8269247
# 33 0.5 0.4 0.1 0  7.089610 0.9430329 1.1322611
# 28 0.4 0.6 0.0 0  7.135880 0.9401943 1.4552036
# 47 1.0 0.0 0.0 0  7.147568 0.9365646 2.5208765
# 46 0.9 0.1 0.0 0  7.296758 0.9310657 2.0456284
# 39 0.7 0.0 0.3 0  8.993889 0.9319335 0.2890558
# 36 0.6 0.1 0.3 0 11.064072 0.9085771 2.3743200
# 27 0.4 0.5 0.1 0 11.660514 0.8779728 4.6843963
# 29 0.5 0.0 0.5 0 12.274232 0.8941560 3.9771649
# 23 0.4 0.1 0.5 0 12.312762 0.8952569 4.0098649
# 35 0.6 0.0 0.4 0 12.349933 0.8935702 3.9786468
# 24 0.4 0.2 0.4 0 12.351319 0.8929907 3.9699285
# 30 0.5 0.1 0.4 0 12.351319 0.8929907 3.9699285
# 19 0.3 0.3 0.4 0 12.353908 0.8945779 4.0027070
# 20 0.3 0.4 0.3 0 12.417381 0.8925181 3.9581093
# 25 0.4 0.3 0.3 0 12.417381 0.8925181 3.9581093
# 21 0.3 0.5 0.2 0 12.442954 0.8930673 3.9298571

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
boxplot(head(df_SS[order(df_SS['rmse']),], 10)[c('a', 'b', 'c', 'd')], main = 'Svalbard spring top 10%')
stripchart(head(df_SS[order(df_SS['rmse']),], 10)[c('a', 'b', 'c', 'd')], vertical = TRUE, add = TRUE, col = 'blue', pch = 19, method = "jitter")
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “Svalbard spring top 10%”

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
boxplot(head(df_SS[order(-df_SS['rmse']),], 10)[c('a', 'b', 'c', 'd')], main = 'Svalbard spring bottom 10%')
stripchart(head(df_SS[order(-df_SS['rmse']),], 10)[c('a', 'b', 'c', 'd')], vertical = TRUE, add = TRUE, col = 2, pch = 19, method = "jitter")
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “Svalbard spring bottom 10%”

# %%
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="Svalbard spring top 10%", col = hcl.colors(20)) 
lines(bird_SS_data$lon, bird_SS_data$lat, col = 'black', lwd = 10)
for (df in SScoordmerged[as.numeric(rownames(head(df_SS[order(df_SS['rmse']),], 10)))])
    {lines(df$x, df$lat, col = 'white')
    }
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “Svalbard spring top 10%”

# %%
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="Svalbard spring bottom 10%", col = hcl.colors(20)) 
lines(bird_SS_data$lon, bird_SS_data$lat, col = 'black', lwd = 10)
for (df in SScoordmerged[as.numeric(rownames(head(df_SS[order(-df_SS['rmse']),], 10)))])
    {lines(df$x, df$lat, col = 'red')
    }
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “Svalbard spring bottom 10%”

# %% [markdown]
# ## Dutch birds

# %%
head(df_NS[order(df_NS['rmse']),], 12)
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
#    a   b   c   d rmse     r         sd_diff
# 22 0.3 0.7 0.0 0 5.480146 0.8702690 0.886882071
# 27 0.4 0.5 0.1 0 5.776583 0.8872044 1.377456278
# 28 0.4 0.6 0.0 0 5.822119 0.8650298 0.001234378
# 13 0.2 0.3 0.5 0 5.878063 0.8968584 0.591672985
# 33 0.5 0.4 0.1 0 5.933918 0.8825956 1.560581149
# 14 0.2 0.4 0.4 0 5.991266 0.8956527 0.690417546
# 15 0.2 0.5 0.3 0 5.997705 0.8947371 0.676085568
# 7  0.1 0.4 0.5 0 6.026640 0.9144099 0.564505295
# 18 0.3 0.2 0.5 0 6.170468 0.8957133 2.160466013
# 19 0.3 0.3 0.4 0 6.205465 0.8877781 2.023145586
# 16 0.2 0.6 0.2 0 6.206784 0.8905852 0.745079265
# 21 0.3 0.5 0.2 0 6.417362 0.8511605 0.265034462

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
boxplot(head(df_NS[order(df_NS['rmse']),], 10)[c('a', 'b', 'c', 'd')], main = 'NL spring top 10%')
stripchart(head(df_NS[order(df_NS['rmse']),], 10)[c('a', 'b', 'c', 'd')], vertical = TRUE, add = TRUE, col = 'blue', pch = 19, method = "jitter")
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “NL spring top 10%”

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
boxplot(head(df_NS[order(-df_NS['rmse']),], 10)[c('a', 'b', 'c', 'd')], main = 'NL spring')
stripchart(head(df_NS[order(-df_NS['rmse']),], 10)[c('a', 'b', 'c', 'd')], vertical = TRUE, add = TRUE, col = 2, pch = 19, method = "jitter")
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “NL spring”

# %%
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="NL spring top 10%", col = hcl.colors(20)) 
lines(bird_NS_data$lon, bird_NS_data$lat, col = 'black', lwd = 10)
for (df in NScoordmerged[as.numeric(rownames(head(df_NS[order(df_NS['rmse']),], 10)))])
    {lines(df$x, df$lat, col = 'white')
    }
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “NL spring top 10%”

# %%
options(repr.plot.width = 12, repr.plot.height = 12)
plot(my_raster$speed, main="NL spring bottom 10%", col = hcl.colors(20)) 
lines(bird_NS_data$lon, bird_NS_data$lat, col = 'black', lwd = 10)
for (df in NScoordmerged[as.numeric(rownames(head(df_NS[order(-df_NS['rmse']),], 5)))])
    {lines(df$x, df$lat, col = 'red')
    }
# Out:
# Warning message in xtfrm.data.frame(x):
# “cannot xtfrm data frames”
# Plot with title “NL spring bottom 10%”

# %% [markdown]
# ### Accumulated cost

# %%
split(coefflist, ceiling(seq_along(coefflist)/4))
# Out:
# $`1`
# [1] 0 0 0 1
#
# $`2`
# [1] 0.0 0.0 0.1 0.9
#
# $`3`
# [1] 0.0 0.0 0.2 0.8
#
# $`4`
# [1] 0.0 0.0 0.3 0.7
#
# $`5`
# [1] 0.0 0.0 0.4 0.6
#
# $`6`
# [1] 0.0 0.0 0.5 0.5
#
# $`7`
# [1] 0.0 0.0 0.6 0.4
#
# $`8`
# [1] 0.0 0.0 0.7 0.3
#
# $`9`
# [1] 0.0 0.0 0.8 0.2
#
# $`10`
# [1] 0.0 0.0 0.9 0.1
#
# $`11`
# [1] 0 0 1 0
#
# $`12`
# [1] 0.0 0.1 0.0 0.9
#
# $`13`
# [1] 0.0 0.1 0.1 0.8
#
# $`14`
# [1] 0.0 0.1 0.2 0.7
#
# $`15`
# [1] 0.0 0.1 0.3 0.6
#
# $`16`
# [1] 0.0 0.1 0.4 0.5
#
# $`17`
# [1] 0.0 0.1 0.5 0.4
#
# $`18`
# [1] 0.0 0.1 0.6 0.3
#
# $`19`
# [1] 0.0 0.1 0.7 0.2
#
# $`20`
# [1] 0.0 0.1 0.8 0.1
#
# $`21`
# [1] 0.0 0.1 0.9 0.0
#
# $`22`
# [1] 0.0 0.2 0.0 0.8
#
# $`23`
# [1] 0.0 0.2 0.1 0.7
#
# $`24`
# [1] 0.0 0.2 0.2 0.6
#
# $`25`
# [1] 0.0 0.2 0.3 0.5
#
# $`26`
# [1] 0.0 0.2 0.4 0.4
#
# $`27`
# [1] 0.0 0.2 0.5 0.3
#
# $`28`
# [1] 0.0 0.2 0.6 0.2
#
# $`29`
# [1] 0.0 0.2 0.8 0.0
#
# $`30`
# [1] 0.0 0.3 0.0 0.7
#
# $`31`
# [1] 0.0 0.3 0.1 0.6
#
# $`32`
# [1] 0.0 0.3 0.2 0.5
#
# $`33`
# [1] 0.0 0.3 0.3 0.4
#
# $`34`
# [1] 0.0 0.3 0.4 0.3
#
# $`35`
# [1] 0.0 0.3 0.5 0.2
#
# $`36`
# [1] 0.0 0.3 0.7 0.0
#
# $`37`
# [1] 0.0 0.4 0.0 0.6
#
# $`38`
# [1] 0.0 0.4 0.1 0.5
#
# $`39`
# [1] 0.0 0.4 0.2 0.4
#
# $`40`
# [1] 0.0 0.4 0.3 0.3
#
# $`41`
# [1] 0.0 0.4 0.4 0.2
#
# $`42`
# [1] 0.0 0.4 0.5 0.1
#
# $`43`
# [1] 0.0 0.4 0.6 0.0
#
# $`44`
# [1] 0.0 0.5 0.0 0.5
#
# $`45`
# [1] 0.0 0.5 0.1 0.4
#
# $`46`
# [1] 0.0 0.5 0.2 0.3
#
# $`47`
# [1] 0.0 0.5 0.3 0.2
#
# $`48`
# [1] 0.0 0.5 0.4 0.1
#
# $`49`
# [1] 0.0 0.5 0.5 0.0
#
# $`50`
# [1] 0.0 0.6 0.0 0.4
#
# $`51`
# [1] 0.0 0.6 0.1 0.3
#
# $`52`
# [1] 0.0 0.6 0.2 0.2
#
# $`53`
# [1] 0.0 0.6 0.4 0.0
#
# $`54`
# [1] 0.0 0.7 0.0 0.3
#
# $`55`
# [1] 0.0 0.7 0.1 0.2
#
# $`56`
# [1] 0.0 0.7 0.3 0.0
#
# $`57`
# [1] 0.0 0.8 0.0 0.2
#
# $`58`
# [1] 0.0 0.8 0.1 0.1
#
# $`59`
# [1] 0.0 0.8 0.2 0.0
#
# $`60`
# [1] 0.0 0.9 0.0 0.1
#
# $`61`
# [1] 0.0 0.9 0.1 0.0
#
# $`62`
# [1] 0 1 0 0
#
# $`63`
# [1] 0.1 0.0 0.0 0.9
#
# $`64`
# [1] 0.1 0.0 0.1 0.8
#
# $`65`
# [1] 0.1 0.0 0.2 0.7
#
# $`66`
# [1] 0.1 0.0 0.3 0.6
#
# $`67`
# [1] 0.1 0.0 0.4 0.5
#
# $`68`
# [1] 0.1 0.0 0.5 0.4
#
# $`69`
# [1] 0.1 0.0 0.6 0.3
#
# $`70`
# [1] 0.1 0.0 0.7 0.2
#
# $`71`
# [1] 0.1 0.0 0.8 0.1
#
# $`72`
# [1] 0.1 0.0 0.9 0.0
#
# $`73`
# [1] 0.1 0.1 0.0 0.8
#
# $`74`
# [1] 0.1 0.1 0.1 0.7
#
# $`75`
# [1] 0.1 0.1 0.2 0.6
#
# $`76`
# [1] 0.1 0.1 0.3 0.5
#
# $`77`
# [1] 0.1 0.1 0.4 0.4
#
# $`78`
# [1] 0.1 0.1 0.5 0.3
#
# $`79`
# [1] 0.1 0.1 0.6 0.2
#
# $`80`
# [1] 0.1 0.1 0.8 0.0
#
# $`81`
# [1] 0.1 0.2 0.0 0.7
#
# $`82`
# [1] 0.1 0.2 0.1 0.6
#
# $`83`
# [1] 0.1 0.2 0.2 0.5
#
# $`84`
# [1] 0.1 0.2 0.3 0.4
#
# $`85`
# [1] 0.1 0.2 0.4 0.3
#
# $`86`
# [1] 0.1 0.2 0.5 0.2
#
# $`87`
# [1] 0.1 0.2 0.7 0.0
#
# $`88`
# [1] 0.1 0.3 0.0 0.6
#
# $`89`
# [1] 0.1 0.3 0.1 0.5
#
# $`90`
# [1] 0.1 0.3 0.2 0.4
#
# $`91`
# [1] 0.1 0.3 0.3 0.3
#
# $`92`
# [1] 0.1 0.3 0.4 0.2
#
# $`93`
# [1] 0.1 0.3 0.5 0.1
#
# $`94`
# [1] 0.1 0.3 0.6 0.0
#
# $`95`
# [1] 0.1 0.4 0.0 0.5
#
# $`96`
# [1] 0.1 0.4 0.1 0.4
#
# $`97`
# [1] 0.1 0.4 0.2 0.3
#
# $`98`
# [1] 0.1 0.4 0.3 0.2
#
# $`99`
# [1] 0.1 0.4 0.4 0.1
#
# $`100`
# [1] 0.1 0.4 0.5 0.0
#
# $`101`
# [1] 0.1 0.5 0.0 0.4
#
# $`102`
# [1] 0.1 0.5 0.1 0.3
#
# $`103`
# [1] 0.1 0.5 0.2 0.2
#
# $`104`
# [1] 0.1 0.5 0.3 0.1
#
# $`105`
# [1] 0.1 0.5 0.4 0.0
#
# $`106`
# [1] 0.1 0.6 0.0 0.3
#
# $`107`
# [1] 0.1 0.6 0.1 0.2
#
# $`108`
# [1] 0.1 0.6 0.3 0.0
#
# $`109`
# [1] 0.1 0.7 0.0 0.2
#
# $`110`
# [1] 0.1 0.7 0.1 0.1
#
# $`111`
# [1] 0.1 0.7 0.2 0.0
#
# $`112`
# [1] 0.1 0.8 0.0 0.1
#
# $`113`
# [1] 0.1 0.8 0.1 0.0
#
# $`114`
# [1] 0.1 0.9 0.0 0.0
#
# $`115`
# [1] 0.2 0.0 0.0 0.8
#
# $`116`
# [1] 0.2 0.0 0.1 0.7
#
# $`117`
# [1] 0.2 0.0 0.2 0.6
#
# $`118`
# [1] 0.2 0.0 0.3 0.5
#
# $`119`
# [1] 0.2 0.0 0.4 0.4
#
# $`120`
# [1] 0.2 0.0 0.5 0.3
#
# $`121`
# [1] 0.2 0.0 0.6 0.2
#
# $`122`
# [1] 0.2 0.0 0.8 0.0
#
# $`123`
# [1] 0.2 0.1 0.0 0.7
#
# $`124`
# [1] 0.2 0.1 0.1 0.6
#
# $`125`
# [1] 0.2 0.1 0.2 0.5
#
# $`126`
# [1] 0.2 0.1 0.3 0.4
#
# $`127`
# [1] 0.2 0.1 0.4 0.3
#
# $`128`
# [1] 0.2 0.1 0.5 0.2
#
# $`129`
# [1] 0.2 0.1 0.7 0.0
#
# $`130`
# [1] 0.2 0.2 0.0 0.6
#
# $`131`
# [1] 0.2 0.2 0.1 0.5
#
# $`132`
# [1] 0.2 0.2 0.2 0.4
#
# $`133`
# [1] 0.2 0.2 0.3 0.3
#
# $`134`
# [1] 0.2 0.2 0.4 0.2
#
# $`135`
# [1] 0.2 0.2 0.5 0.1
#
# $`136`
# [1] 0.2 0.2 0.6 0.0
#
# $`137`
# [1] 0.2 0.3 0.0 0.5
#
# $`138`
# [1] 0.2 0.3 0.1 0.4
#
# $`139`
# [1] 0.2 0.3 0.2 0.3
#
# $`140`
# [1] 0.2 0.3 0.3 0.2
#
# $`141`
# [1] 0.2 0.3 0.4 0.1
#
# $`142`
# [1] 0.2 0.3 0.5 0.0
#
# $`143`
# [1] 0.2 0.4 0.0 0.4
#
# $`144`
# [1] 0.2 0.4 0.1 0.3
#
# $`145`
# [1] 0.2 0.4 0.2 0.2
#
# $`146`
# [1] 0.2 0.4 0.4 0.0
#
# $`147`
# [1] 0.2 0.5 0.0 0.3
#
# $`148`
# [1] 0.2 0.5 0.1 0.2
#
# $`149`
# [1] 0.2 0.5 0.3 0.0
#
# $`150`
# [1] 0.2 0.6 0.0 0.2
#
# $`151`
# [1] 0.2 0.6 0.1 0.1
#
# $`152`
# [1] 0.2 0.6 0.2 0.0
#
# $`153`
# [1] 0.2 0.8 0.0 0.0
#
# $`154`
# [1] 0.3 0.0 0.0 0.7
#
# $`155`
# [1] 0.3 0.0 0.1 0.6
#
# $`156`
# [1] 0.3 0.0 0.2 0.5
#
# $`157`
# [1] 0.3 0.0 0.3 0.4
#
# $`158`
# [1] 0.3 0.0 0.4 0.3
#
# $`159`
# [1] 0.3 0.0 0.5 0.2
#
# $`160`
# [1] 0.3 0.0 0.7 0.0
#
# $`161`
# [1] 0.3 0.1 0.0 0.6
#
# $`162`
# [1] 0.3 0.1 0.1 0.5
#
# $`163`
# [1] 0.3 0.1 0.2 0.4
#
# $`164`
# [1] 0.3 0.1 0.3 0.3
#
# $`165`
# [1] 0.3 0.1 0.4 0.2
#
# $`166`
# [1] 0.3 0.1 0.5 0.1
#
# $`167`
# [1] 0.3 0.1 0.6 0.0
#
# $`168`
# [1] 0.3 0.2 0.0 0.5
#
# $`169`
# [1] 0.3 0.2 0.1 0.4
#
# $`170`
# [1] 0.3 0.2 0.2 0.3
#
# $`171`
# [1] 0.3 0.2 0.3 0.2
#
# $`172`
# [1] 0.3 0.2 0.4 0.1
#
# $`173`
# [1] 0.3 0.2 0.5 0.0
#
# $`174`
# [1] 0.3 0.3 0.0 0.4
#
# $`175`
# [1] 0.3 0.3 0.1 0.3
#
# $`176`
# [1] 0.3 0.3 0.2 0.2
#
# $`177`
# [1] 0.3 0.3 0.4 0.0
#
# $`178`
# [1] 0.3 0.4 0.0 0.3
#
# $`179`
# [1] 0.3 0.4 0.1 0.2
#
# $`180`
# [1] 0.3 0.4 0.3 0.0
#
# $`181`
# [1] 0.3 0.5 0.0 0.2
#
# $`182`
# [1] 0.3 0.5 0.1 0.1
#
# $`183`
# [1] 0.3 0.5 0.2 0.0
#
# $`184`
# [1] 0.3 0.7 0.0 0.0
#
# $`185`
# [1] 0.4 0.0 0.0 0.6
#
# $`186`
# [1] 0.4 0.0 0.1 0.5
#
# $`187`
# [1] 0.4 0.0 0.2 0.4
#
# $`188`
# [1] 0.4 0.0 0.3 0.3
#
# $`189`
# [1] 0.4 0.0 0.4 0.2
#
# $`190`
# [1] 0.4 0.0 0.5 0.1
#
# $`191`
# [1] 0.4 0.0 0.6 0.0
#
# $`192`
# [1] 0.4 0.1 0.0 0.5
#
# $`193`
# [1] 0.4 0.1 0.1 0.4
#
# $`194`
# [1] 0.4 0.1 0.2 0.3
#
# $`195`
# [1] 0.4 0.1 0.3 0.2
#
# $`196`
# [1] 0.4 0.1 0.4 0.1
#
# $`197`
# [1] 0.4 0.1 0.5 0.0
#
# $`198`
# [1] 0.4 0.2 0.0 0.4
#
# $`199`
# [1] 0.4 0.2 0.1 0.3
#
# $`200`
# [1] 0.4 0.2 0.2 0.2
#
# $`201`
# [1] 0.4 0.2 0.4 0.0
#
# $`202`
# [1] 0.4 0.3 0.0 0.3
#
# $`203`
# [1] 0.4 0.3 0.1 0.2
#
# $`204`
# [1] 0.4 0.3 0.3 0.0
#
# $`205`
# [1] 0.4 0.4 0.0 0.2
#
# $`206`
# [1] 0.4 0.4 0.1 0.1
#
# $`207`
# [1] 0.4 0.4 0.2 0.0
#
# $`208`
# [1] 0.4 0.5 0.0 0.1
#
# $`209`
# [1] 0.4 0.5 0.1 0.0
#
# $`210`
# [1] 0.4 0.6 0.0 0.0
#
# $`211`
# [1] 0.5 0.0 0.0 0.5
#
# $`212`
# [1] 0.5 0.0 0.1 0.4
#
# $`213`
# [1] 0.5 0.0 0.2 0.3
#
# $`214`
# [1] 0.5 0.0 0.3 0.2
#
# $`215`
# [1] 0.5 0.0 0.4 0.1
#
# $`216`
# [1] 0.5 0.0 0.5 0.0
#
# $`217`
# [1] 0.5 0.1 0.0 0.4
#
# $`218`
# [1] 0.5 0.1 0.1 0.3
#
# $`219`
# [1] 0.5 0.1 0.2 0.2
#
# $`220`
# [1] 0.5 0.1 0.3 0.1
#
# $`221`
# [1] 0.5 0.1 0.4 0.0
#
# $`222`
# [1] 0.5 0.2 0.0 0.3
#
# $`223`
# [1] 0.5 0.2 0.1 0.2
#
# $`224`
# [1] 0.5 0.2 0.3 0.0
#
# $`225`
# [1] 0.5 0.3 0.0 0.2
#
# $`226`
# [1] 0.5 0.3 0.1 0.1
#
# $`227`
# [1] 0.5 0.3 0.2 0.0
#
# $`228`
# [1] 0.5 0.4 0.0 0.1
#
# $`229`
# [1] 0.5 0.4 0.1 0.0
#
# $`230`
# [1] 0.5 0.5 0.0 0.0
#
# $`231`
# [1] 0.6 0.0 0.0 0.4
#
# $`232`
# [1] 0.6 0.0 0.1 0.3
#
# $`233`
# [1] 0.6 0.0 0.2 0.2
#
# $`234`
# [1] 0.6 0.0 0.4 0.0
#
# $`235`
# [1] 0.6 0.1 0.0 0.3
#
# $`236`
# [1] 0.6 0.1 0.1 0.2
#
# $`237`
# [1] 0.6 0.1 0.3 0.0
#
# $`238`
# [1] 0.6 0.2 0.0 0.2
#
# $`239`
# [1] 0.6 0.2 0.1 0.1
#
# $`240`
# [1] 0.6 0.2 0.2 0.0
#
# $`241`
# [1] 0.6 0.4 0.0 0.0
#
# $`242`
# [1] 0.7 0.0 0.0 0.3
#
# $`243`
# [1] 0.7 0.0 0.1 0.2
#
# $`244`
# [1] 0.7 0.0 0.3 0.0
#
# $`245`
# [1] 0.7 0.1 0.0 0.2
#
# $`246`
# [1] 0.7 0.1 0.1 0.1
#
# $`247`
# [1] 0.7 0.1 0.2 0.0
#
# $`248`
# [1] 0.7 0.3 0.0 0.0
#
# $`249`
# [1] 0.8 0.0 0.0 0.2
#
# $`250`
# [1] 0.8 0.0 0.1 0.1
#
# $`251`
# [1] 0.8 0.0 0.2 0.0
#
# $`252`
# [1] 0.8 0.1 0.0 0.1
#
# $`253`
# [1] 0.8 0.1 0.1 0.0
#
# $`254`
# [1] 0.8 0.2 0.0 0.0
#
# $`255`
# [1] 0.9 0.0 0.0 0.1
#
# $`256`
# [1] 0.9 0.0 0.1 0.0
#
# $`257`
# [1] 0.9 0.1 0.0 0.0
#
# $`258`
# [1] 1 0 0 0

# %%
accCost_1 <- accCost(mylist[[1]], A)
accCost_11 <- accCost(mylist[[11]], A)
accCost_62 <- accCost(mylist[[62]], A)
accCost_258 <- accCost(mylist[[258]], A)

# %%
accCost_1[accCost_1 > 1000000] <- NA
accCost_11[accCost_11 > 1000000] <- NA
accCost_62[accCost_62 > 1000000] <- NA
accCost_258[accCost_258 > 1000000] <- NA

# %%
# Plot shortest paths (SpatialLines) for Svalbard birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(accCost_258 , main="accCost support Svalbard spring", col = hcl.colors(20)) 
for (df in SScoordmerged[as.numeric(rownames(df_SS[df_SS$a > 0.8, ]))])
    {lines(df$x, df$lat, col = 'white')
    }
# Out:
# Plot with title “accCost support Svalbard spring”

# %%
# Plot shortest paths (SpatialLines) for Svalbard birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(accCost_62 , main="accCost distance Svalbard spring", col = hcl.colors(20)) 
for (df in SScoordmerged[as.numeric(rownames(df_SS[df_SS$b > 0.8, ]))])
    {lines(df$x, df$lat, col = 'white')
    }
# Out:
# Plot with title “accCost distance Svalbard spring”

# %%
# Plot shortest paths (SpatialLines) for Svalbard birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(accCost_11 , main="accCost food Svalbard spring", col = hcl.colors(20)) 
for (df in SScoordmerged[as.numeric(rownames(df_SS[df_SS$c > 0.8, ]))])
    {lines(df$x, df$lat, col = 'white')
    }
# Out:
# Plot with title “accCost food Svalbard spring”

# %%
# Plot shortest paths (SpatialLines) for Svalbard birds
options(repr.plot.width = 12, repr.plot.height = 12)
plot(accCost_1 , main="accCost crosswind Svalbard spring", col = hcl.colors(20)) 
for (df in SScoordmerged[as.numeric(rownames(df_SS[df_SS$d > 0.8, ]))])
    {lines(df$x, df$lat, col = 'white')
    }
# Out:
# Plot with title “accCost crosswind Svalbard spring”
