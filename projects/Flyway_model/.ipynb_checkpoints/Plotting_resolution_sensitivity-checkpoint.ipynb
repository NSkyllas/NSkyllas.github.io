# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from cartopy import crs as ccrs
from shapely.geometry import Point, LineString, shape
import matplotlib.colors
import cartopy.feature as cfeature
from haversine import haversine
import numpy as np

# %%
for i in range(1, 6):
    exec(f"dfss{i} = pd.read_csv('SScoordinates{i}_a1b1c5d5_chla1.csv')")
    exec(f"dfns{i} = pd.read_csv('NScoordinates{i}_a1b1c5d5_chla1.csv')")
    exec(f"dfsa_am{i} = pd.read_csv('SAamcoordinates{i}_a1b1c5d5_chla1.csv')")
    exec(f"dfsa_af{i} = pd.read_csv('SAafcoordinates{i}_a1b1c5d5_chla1.csv')")
    exec(f"dfna{i} = pd.read_csv('NAcoordinates{i}_a1b1c5d5_chla1.csv')")

# %%
for i in range(1, 4):
    exec(f"dfaa{i} = pd.read_csv('AAcoordinates{i}_a1b1c5d5_chla08.csv')")
    exec(f"dfca{i} = pd.read_csv('CAcoordinates{i}_a1b1c5d5_chla08.csv')")

# %%
dfss1
# Out:
#        matrix   x     y
# 0           1 -25 -73.5
# 1           1 -26 -73.5
# 2           1 -27 -72.5
# 3           1 -27 -71.5
# 4           1 -27 -70.5
# ...       ...  ..   ...
# 10966      54 -23  60.5
# 10967      54 -22  61.5
# 10968      54 -21  62.5
# 10969      54 -21  63.5
# 10970      54 -20  64.5
#
# [10971 rows x 3 columns]

# %%
# Turn it to a GeoDataFrame
for i in range(1, 6):
    exec(f"gdfss{i} = gpd.GeoDataFrame(dfss{i}, geometry = gpd.points_from_xy(dfss{i}['x'], dfss{i}['y']))")
    exec(f"gdfns{i} = gpd.GeoDataFrame(dfns{i}, geometry = gpd.points_from_xy(dfns{i}['x'], dfns{i}['y']))")
    exec(f"gdfsa_am{i} = gpd.GeoDataFrame(dfsa_am{i}, geometry = gpd.points_from_xy(dfsa_am{i}['x'], dfsa_am{i}['y']))")
    exec(f"gdfsa_af{i} = gpd.GeoDataFrame(dfsa_af{i}, geometry = gpd.points_from_xy(dfsa_af{i}['x'], dfsa_af{i}['y']))")
    exec(f"gdfna{i} = gpd.GeoDataFrame(dfna{i}, geometry = gpd.points_from_xy(dfna{i}['x'], dfna{i}['y']))")

# %%
# Turn it to a GeoDataFrame
for i in range(1, 4):
    exec(f"gdfaa{i} = gpd.GeoDataFrame(dfaa{i}, geometry = gpd.points_from_xy(dfaa{i}['x'], dfaa{i}['y']))")
    exec(f"gdfca{i} = gpd.GeoDataFrame(dfca{i}, geometry = gpd.points_from_xy(dfca{i}['x'], dfca{i}['y']))")

# %%
gdfss1
# Out:
#        matrix   x     y                     geometry
# 0           1 -25 -73.5  POINT (-25.00000 -73.50000)
# 1           1 -26 -73.5  POINT (-26.00000 -73.50000)
# 2           1 -27 -72.5  POINT (-27.00000 -72.50000)
# 3           1 -27 -71.5  POINT (-27.00000 -71.50000)
# 4           1 -27 -70.5  POINT (-27.00000 -70.50000)
# ...       ...  ..   ...                          ...
# 10966      54 -23  60.5   POINT (-23.00000 60.50000)
# 10967      54 -22  61.5   POINT (-22.00000 61.50000)
# 10968      54 -21  62.5   POINT (-21.00000 62.50000)
# 10969      54 -21  63.5   POINT (-21.00000 63.50000)
# 10970      54 -20  64.5   POINT (-20.00000 64.50000)
#
# [10971 rows x 4 columns]

# %%
fig, ax = plt.subplots(ncols = 2, figsize = (12, 6))#, subplot_kw={'projection': ccrs.PlateCarree()})
gdfss1.plot(ax = ax[0], alpha = 0.01)
gdfss2.plot(ax = ax[0], alpha = 0.01)
gdfss3.plot(ax = ax[0], alpha = 0.01)
gdfss4.plot(ax = ax[0], alpha = 0.01)
gdfss5.plot(ax = ax[0], alpha = 0.01)

gdfns1.plot(ax = ax[1], alpha = 0.01)
gdfns2.plot(ax = ax[1], alpha = 0.01)
gdfns3.plot(ax = ax[1], alpha = 0.01)
gdfns4.plot(ax = ax[1], alpha = 0.01)
gdfns5.plot(ax = ax[1], alpha = 0.01)
# Out:
# <Axes: >

# %%
# Collect all the coordinates and put them in 1 list per path
for i in range(1, 6):
    exec(f"gdfss2_{i} = gpd.GeoDataFrame(gdfss{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")
    exec(f"gdfns2_{i} = gpd.GeoDataFrame(gdfns{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")
    exec(f"gdfsa_am2_{i} = gpd.GeoDataFrame(gdfsa_am{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")
    exec(f"gdfsa_af2_{i} = gpd.GeoDataFrame(gdfsa_af{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")
    exec(f"gdfna2_{i} = gpd.GeoDataFrame(gdfna{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")

# %%
# Collect all the coordinates and put them in 1 list per path
for i in range(1, 4):
    exec(f"gdfaa2_{i} = gpd.GeoDataFrame(gdfaa{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")
    exec(f"gdfca2_{i} = gpd.GeoDataFrame(gdfca{i}.groupby(['matrix'])['geometry'].apply(lambda x: LineString(x.tolist())))")

# %%
gdfss2_1
# Out:
#                                                  geometry
# matrix
# 1       LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 2       LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 3       LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 4       LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 5       LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 6       LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 7       LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 8       LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 9       LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 10      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 11      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 12      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 13      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 14      LINESTRING (-25.00000 -73.50000, -24.00000 -72...
# 15      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 16      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 17      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 18      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 19      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 20      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 21      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 22      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 23      LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 24      LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 25      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 26      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 27      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 28      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 29      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 30      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 31      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 32      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 33      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 34      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 35      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 36      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 37      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 38      LINESTRING (-25.00000 -73.50000, -26.00000 -74...
# 39      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 40      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 41      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 42      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 43      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 44      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 45      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 46      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 47      LINESTRING (-25.00000 -73.50000, -26.00000 -73...
# 48      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 49      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 50      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 51      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 52      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 53      LINESTRING (-25.00000 -73.50000, -26.00000 -72...
# 54      LINESTRING (-25.00000 -73.50000, -26.00000 -72...

# %%
for i in range(1, 6):
    exec(f"gdfss2_{i} = gpd.GeoDataFrame(gdfss2_{i})")
    exec(f"gdfns2_{i} = gpd.GeoDataFrame(gdfns2_{i})")
    exec(f"gdfsa_am2_{i} = gpd.GeoDataFrame(gdfsa_am2_{i})")
    exec(f"gdfsa_af2_{i} = gpd.GeoDataFrame(gdfsa_af2_{i})")
    exec(f"gdfna2_{i} = gpd.GeoDataFrame(gdfna2_{i})")

    exec(f"gdfss2_{i} = gdfss2_{i}.set_crs(crs=4326, allow_override=True)")
    exec(f"gdfns2_{i} = gdfns2_{i}.set_crs(crs=4326, allow_override=True)")
    exec(f"gdfsa_am2_{i} = gdfsa_am2_{i}.set_crs(crs=4326, allow_override=True)")
    exec(f"gdfsa_af2_{i} = gdfsa_af2_{i}.set_crs(crs=4326, allow_override=True)")
    exec(f"gdfna2_{i} = gdfna2_{i}.set_crs(crs=4326, allow_override=True)")

# %%
for i in range(1, 4):
    exec(f"gdfaa2_{i} = gpd.GeoDataFrame(gdfaa2_{i})")
    exec(f"gdfca2_{i} = gpd.GeoDataFrame(gdfca2_{i})")

    exec(f"gdfaa2_{i} = gdfaa2_{i}.set_crs(crs=4326, allow_override=True)")
    exec(f"gdfca2_{i} = gdfca2_{i}.set_crs(crs=4326, allow_override=True)")

# %%
# Calculate each path's length (in km)
for i in range(1, 6):
    exec(f"gdfss2_{i}['length_km'] = gdfss2_{i}.geometry.to_crs(3857).length/1000")
    exec(f"gdfns2_{i}['length_km'] = gdfns2_{i}.geometry.to_crs(3857).length/1000")
    exec(f"gdfsa_am2_{i}['length_km'] = gdfsa_am2_{i}.geometry.to_crs(3857).length/1000")
    exec(f"gdfsa_af2_{i}['length_km'] = gdfsa_af2_{i}.geometry.to_crs(3857).length/1000")
    exec(f"gdfna2_{i}['length_km'] = gdfna2_{i}.geometry.to_crs(3857).length/1000")

# %%
# Calculate each path's length (in km)
for i in range(1, 4):
    exec(f"gdfaa2_{i}['length_km'] = gdfaa2_{i}.geometry.to_crs(3857).length/1000")
    exec(f"gdfca2_{i}['length_km'] = gdfca2_{i}.geometry.to_crs(3857).length/1000")

# %%
gdfss2_1
# Out:
#                                                  geometry      length_km
# matrix
# 1       LINESTRING (-25.00000 -73.50000, -26.00000 -73...   27260.623088
# 2       LINESTRING (-25.00000 -73.50000, -26.00000 -73...  105160.815265
# 3       LINESTRING (-25.00000 -73.50000, -26.00000 -74...  162076.066717
# 4       LINESTRING (-25.00000 -73.50000, -26.00000 -74...  164687.798100
# 5       LINESTRING (-25.00000 -73.50000, -26.00000 -73...   25516.919811
# 6       LINESTRING (-25.00000 -73.50000, -26.00000 -72...   25662.620909
# 7       LINESTRING (-25.00000 -73.50000, -26.00000 -73...   24430.167881
# 8       LINESTRING (-25.00000 -73.50000, -26.00000 -74...  154183.626356
# 9       LINESTRING (-25.00000 -73.50000, -26.00000 -74...  154862.815411
# 10      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   25185.393237
# 11      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   23237.219619
# 12      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   23742.081713
# 13      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24860.820944
# 14      LINESTRING (-25.00000 -73.50000, -24.00000 -72...   24705.856186
# 15      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   22307.729191
# 16      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   23971.509218
# 17      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   22781.918932
# 18      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   22285.742439
# 19      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   22270.324801
# 20      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   25668.942903
# 21      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   25475.864221
# 22      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24392.759834
# 23      LINESTRING (-25.00000 -73.50000, -26.00000 -74...  155442.440214
# 24      LINESTRING (-25.00000 -73.50000, -26.00000 -74...  156714.609512
# 25      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24969.655079
# 26      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24230.525214
# 27      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   24639.620684
# 28      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24872.312459
# 29      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24842.261848
# 30      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   23822.949362
# 31      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24266.595019
# 32      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24456.961877
# 33      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   23579.373232
# 34      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   22843.691762
# 35      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24851.055299
# 36      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   24551.476332
# 37      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   26360.055677
# 38      LINESTRING (-25.00000 -73.50000, -26.00000 -74...  157021.036747
# 39      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24725.299249
# 40      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26210.251269
# 41      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24730.733554
# 42      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26402.149106
# 43      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   24182.672965
# 44      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   25974.147405
# 45      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26590.306144
# 46      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   27002.730866
# 47      LINESTRING (-25.00000 -73.50000, -26.00000 -73...   28438.805049
# 48      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26498.616026
# 49      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26655.829422
# 50      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26240.448419
# 51      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26856.774486
# 52      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   28336.634677
# 53      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   26820.689068
# 54      LINESTRING (-25.00000 -73.50000, -26.00000 -72...   27867.005789

# %%
# For example, the best Svalbard Spring paths have high alphas (maximising wind support), and then relatively high deltas (minimising crosswinds). Maximising food (gamma)
# or minimising the distance (beta) are not important. This changes for different seasons and populations
fig, ax = plt.subplots(ncols = 2, nrows = 1, figsize = (5, 8), subplot_kw={'projection': ccrs.PlateCarree()})

gdfss2_1[gdfss2_1.length_km < 100000].plot(ax = ax[0], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 4, transform = ccrs.PlateCarree())
gdfss2_2[gdfss2_2.length_km < 100000].plot(ax = ax[0], color = 'green', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfss2_3[gdfss2_3.length_km < 100000].plot(ax = ax[0], color = 'red', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
#gdfss2_4[gdfss2_4.length_km < 100000].plot(ax = ax[0], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
gdfss2_5[gdfss2_5.length_km < 100000].plot(ax = ax[0], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())

ax[0].coastlines()
ax[0].set_global()
ax[0].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[0].set_title('SS four starting loations', fontsize = 10)
ax[0].set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())

gdfns2_1[gdfns2_1.length_km < 100000].plot(ax = ax[1], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 4, transform = ccrs.PlateCarree())
gdfns2_2[gdfns2_2.length_km < 100000].plot(ax = ax[1], color = 'green', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfns2_3[gdfns2_3.length_km < 100000].plot(ax = ax[1], color = 'red', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
#gdfns2_4[gdfns2_4.length_km < 100000].plot(ax = ax[1], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
gdfns2_5[gdfns2_5.length_km < 100000].plot(ax = ax[1], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())

ax[1].coastlines()
ax[1].set_global()
ax[1].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[1].set_title('NS four startng locations', fontsize = 10)
ax[1].set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())

ax[0].text(16, -80, 'a', fontsize = 20)
ax[1].text(16, -80, 'b', fontsize = 20)

plt.tight_layout()

# %%
# For example, the best Svalbard Spring paths have high alphas (maximising wind support), and then relatively high deltas (minimising crosswinds). Maximising food (gamma)
# or minimising the distance (beta) are not important. This changes for different seasons and populations
fig, ax = plt.subplots(ncols = 3, nrows = 1, figsize = (7.5, 8), subplot_kw={'projection': ccrs.PlateCarree()})

gdfsa_am2_1[gdfsa_am2_1.length_km < 100000].plot(ax = ax[0], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 4, transform = ccrs.PlateCarree())
gdfsa_am2_2[gdfsa_am2_2.length_km < 100000].plot(ax = ax[0], color = 'green', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfsa_am2_3[gdfsa_am2_3.length_km < 100000].plot(ax = ax[0], color = 'red', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfsa_am2_4[gdfsa_am2_4.length_km < 100000].plot(ax = ax[0], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfsa_am2_5[gdfsa_am2_5.length_km < 100000].plot(ax = ax[0], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())

ax[0].coastlines()
ax[0].set_global()
ax[0].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[0].set_title('SA_am four starting loations', fontsize = 10)
ax[0].set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())

gdfsa_af2_1[gdfsa_af2_1.length_km < 100000].plot(ax = ax[1], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 4, transform = ccrs.PlateCarree())
gdfsa_af2_2[gdfsa_af2_2.length_km < 100000].plot(ax = ax[1], color = 'green', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfsa_af2_3[gdfsa_af2_3.length_km < 100000].plot(ax = ax[1], color = 'red', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfsa_af2_4[gdfsa_af2_4.length_km < 100000].plot(ax = ax[1], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())
gdfsa_af2_5[gdfsa_af2_5.length_km < 100000].plot(ax = ax[1], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())

ax[1].coastlines()
ax[1].set_global()
ax[1].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[1].set_title('SA_af four starting loations', fontsize = 10)
ax[1].set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())

gdfna2_1[gdfna2_1.length_km < 100000].plot(ax = ax[2], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, label = 'original', linewidth = 4, transform = ccrs.PlateCarree())
gdfna2_2[gdfna2_2.length_km < 100000].plot(ax = ax[2], color = 'green', vmin = 0, vmax = 1, alpha = 0.2, legend = True, label = '-10 lon', linewidth = 1, transform = ccrs.PlateCarree())
gdfna2_3[gdfna2_3.length_km < 100000].plot(ax = ax[2], color = 'red', vmin = 0, vmax = 1, alpha = 0.2, legend = True, label = '+10 lon', linewidth = 1, transform = ccrs.PlateCarree())
gdfna2_4[gdfna2_4.length_km < 100000].plot(ax = ax[2], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, label = '+10 lat', linewidth = 1, transform = ccrs.PlateCarree())
gdfna2_5[gdfna2_5.length_km < 100000].plot(ax = ax[2], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, label = '-10 lat', linewidth = 1, transform = ccrs.PlateCarree())

ax[2].coastlines()
ax[2].set_global()
ax[2].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[2].set_title('NA four startng locations', fontsize = 10)
ax[2].set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())

ax[0].text(16, -80, 'c', fontsize = 20)
ax[1].text(16, -80, 'd', fontsize = 20)
ax[2].text(16, -80, 'e', fontsize = 20)
ax[2].legend(loc = 3)

plt.tight_layout()

# %%
# For example, the best Svalbard Spring paths have high alphas (maximising wind support), and then relatively high deltas (minimising crosswinds). Maximising food (gamma)
# or minimising the distance (beta) are not important. This changes for different seasons and populations
fig, ax = plt.subplots(ncols = 2, nrows = 1, figsize = (5, 8), subplot_kw={'projection': ccrs.PlateCarree(central_longitude = 180)})

gdfaa2_1[gdfss2_1.length_km < 50000].plot(ax = ax[0], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 4, transform = ccrs.PlateCarree())
gdfaa2_2[gdfss2_2.length_km < 50000].plot(ax = ax[0], color = 'green', vmin = 0, vmax = 1, alpha = 0.3, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
gdfaa2_3[gdfss2_3.length_km < 50000].plot(ax = ax[0], color = 'red', vmin = 0, vmax = 1, alpha = 0.3, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
#gdfss2_4[gdfss2_4.length_km < 100000].plot(ax = ax[0], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
#gdfss2_5[gdfss2_5.length_km < 100000].plot(ax = ax[0], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())

ax[0].coastlines()
ax[0].set_global()
ax[0].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[0].set_title('AA four starting loations', fontsize = 10)
ax[0].set_extent([130, 290, -85, 85], crs = ccrs.PlateCarree())

gdfca2_1[gdfca2_1.length_km < 70000].plot(ax = ax[1], color = 'black', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 4, transform = ccrs.PlateCarree())
gdfca2_2[gdfca2_2.length_km < 70000].plot(ax = ax[1], color = 'green', vmin = 0, vmax = 1, alpha = 0.3, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
gdfca2_3[gdfca2_3.length_km < 70000].plot(ax = ax[1], color = 'red', vmin = 0, vmax = 1, alpha = 0.3, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
#gdfns2_4[gdfns2_4.length_km < 100000].plot(ax = ax[1], color = 'blue', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 2, transform = ccrs.PlateCarree())
#gdfns2_5[gdfns2_5.length_km < 100000].plot(ax = ax[1], color = 'orange', vmin = 0, vmax = 1, alpha = 0.2, legend = True, linewidth = 1, transform = ccrs.PlateCarree())

ax[1].coastlines()
ax[1].set_global()
ax[1].add_feature(cfeature.OCEAN, facecolor = 'silver')
ax[1].set_title('CA four startng locations', fontsize = 10)
ax[1].set_extent([130, 290, -85, 85], crs = ccrs.PlateCarree())

ax[0].text(90, -85, 'f', fontsize = 20)
ax[1].text(90, -85, 'g', fontsize = 20)

plt.tight_layout()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
#top20_ss_ns.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
top20_ss.plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
ax.plot(bird_SS.lon_median10, 
     bird_SS.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--')
ax.fill_betweenx(bird_SS.lat_median10, 
                 bird_SS.lon_median10 + bird_SS.lon_sd_10,
                bird_SS.lon_median10 - bird_SS.lon_sd_10, color = 'yellow', alpha = 0.5)

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Svalbard spring')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
top20_ss_ns.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
top20_ss.plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
ax.plot(bird_SS.lon_median10, 
     bird_SS.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--')
ax.fill_betweenx(bird_SS.lat_median10, 
                 bird_SS.lon_median10 + bird_SS.lon_sd_10,
                bird_SS.lon_median10 - bird_SS.lon_sd_10, color = 'yellow', alpha = 0.5)

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Svalbard spring')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
#top20_sa_am_na.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
gdfsa_am2.sort_values(by = 'rmse').iloc[:20, :].plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
ax.plot(bird_SA_am.lon_median10, 
     bird_SA_am.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--')
ax.fill_betweenx(bird_SA_am.lat_median10, 
                 bird_SA_am.lon_median10 + bird_SA_am.lon_sd_10,
                bird_SA_am.lon_median10 - bird_SA_am.lon_sd_10, color = 'yellow', alpha = 0.5)

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Svalbard am autumn')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
#top20_sa_af_na.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
gdfsa_af2.sort_values(by = 'rmse').iloc[:20, :].plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
ax.plot(bird_SA_af.lon_median10, 
     bird_SA_af.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--')
ax.fill_betweenx(bird_SA_af.lat_median10, 
                 bird_SA_af.lon_median10 + bird_SA_af.lon_sd_10,
                bird_SA_af.lon_median10 - bird_SA_af.lon_sd_10, color = 'yellow', alpha = 0.5)

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Svalbard af autumn')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
#top20_ns_ss.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2, label = 'top 20 simulations \n(alternative behaviour)')
top20_ns.plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2, label = 'top 20 simulations')
ax.plot(bird_NS.lon_median10, 
     bird_NS.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--', label = 'mean GLS position')
ax.fill_betweenx(bird_NS.lat_median10, 
                 bird_NS.lon_median10 + bird_NS.lon_sd_10,
                bird_NS.lon_median10 - bird_NS.lon_sd_10, color = 'yellow', alpha = 0.5, label = '1σ of GLS positions')

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Netherlands spring')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
plt.legend(loc = 3, prop={'size': 8})
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
top20_ns_ss.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2, label = 'top 20 simulations \n(alternative behaviour)')
top20_ns.plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2, label = 'top 20 simulations')
ax.plot(bird_NS.lon_median10, 
     bird_NS.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--', label = 'mean GLS position')
ax.fill_betweenx(bird_NS.lat_median10, 
                 bird_NS.lon_median10 + bird_NS.lon_sd_10,
                bird_NS.lon_median10 - bird_NS.lon_sd_10, color = 'yellow', alpha = 0.5, label = '1σ of GLS positions')

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Netherlands spring')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
plt.legend(loc = 3, prop={'size': 8})
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
#top20_na_sa_am.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
top20_na.plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2, label = 'top 20 simulations')
ax.plot(bird_NA.lon_median10, 
     bird_NA.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--', label = 'mean GLS position')
ax.fill_betweenx(bird_NA.lat_median10, 
                 bird_NA.lon_median10 + bird_NA.lon_sd_10,
                bird_NA.lon_median10 - bird_NA.lon_sd_10, color = 'yellow', alpha = 0.5, label = '1σ of GLS positions')

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Netherlands autumn')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
#plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(ncols = 1, figsize = (12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
top20_na_sa_af.plot(ax = ax, color = 'red', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2)
top20_na.plot(ax = ax, color = 'green', vmin = 0, vmax = 1, alpha = 0.6, legend = True, linewidth = 2, label = 'top 20 simulations')
ax.plot(bird_NA.lon_median10, 
     bird_NA.lat_median10, zorder = 3, linewidth = 3, color = 'yellow', linestyle = '--', label = 'mean GLS position')
ax.fill_betweenx(bird_NA.lat_median10, 
                 bird_NA.lon_median10 + bird_NA.lon_sd_10,
                bird_NA.lon_median10 - bird_NA.lon_sd_10, color = 'yellow', alpha = 0.5, label = '1σ of GLS positions')

ax.coastlines()
ax.set_global()
ax.add_feature(cfeature.OCEAN, facecolor = 'silver')
ax.set_title('top 20 Netherlands autumn')
ax.set_extent([-70, 25, -85, 85], crs = ccrs.PlateCarree())
#plt.legend()
plt.show()

# %%
gdfss2[gdfss2.rmse < 2500][['a', 'b', 'c', 'd', 'length_km', 'rmse']].corr().style.background_gradient(cmap = 'RdBu_r', vmin = -1, vmax = 1)

# %%
pd.plotting.scatter_matrix(gdfss2[gdfss2.rmse < 2500][['rmse', 'a', 'b', 'c', 'd', 'length_km']], figsize = (8, 8))
plt.show()

# %%
gdfns2[gdfns2.rmse < 2500][['a', 'b', 'c', 'd', 'length_km', 'rmse']].corr().style.background_gradient(cmap = 'RdBu_r', vmin = -1, vmax = 1)

# %%
pd.plotting.scatter_matrix(gdfns2[gdfns2.rmse < 2500][['rmse', 'a', 'b', 'c', 'd', 'length_km']], figsize = (8, 8))
plt.show()

# %%
gdfsa_am2[gdfsa_am2.rmse < 2500][['a', 'b', 'c', 'd', 'length_km', 'rmse']].corr().style.background_gradient(cmap = 'RdBu_r', vmin = -1, vmax = 1)

# %%
pd.plotting.scatter_matrix(gdfsa_am2[gdfsa_am2.rmse < 2500][['rmse', 'a', 'b', 'c', 'd', 'length_km']], figsize = (8, 8))
plt.show()

# %%
gdfsa_af2[gdfsa_af2.rmse < 2500][['a', 'b', 'c', 'd', 'length_km', 'rmse']].corr().style.background_gradient(cmap = 'RdBu_r', vmin = -1, vmax = 1)

# %%
pd.plotting.scatter_matrix(gdfsa_af2[gdfsa_af2.rmse < 2500][['rmse', 'a', 'b', 'c', 'd', 'length_km']], figsize = (8, 8))
plt.show()

# %%
gdfna2[['a', 'b', 'c', 'd', 'length_km', 'rmse']].corr().style.background_gradient(cmap = 'RdBu_r', vmin = -1, vmax = 1)

# %%
pd.plotting.scatter_matrix(gdfna2[gdfna2.rmse < 2500][['rmse', 'a', 'b', 'c', 'd', 'length_km']], figsize = (8, 8))
plt.show()

# %%
plt.figure(figsize = (3, 2))
gdfss2[gdfss2.rmse < 2500]['length_km'].plot.hist()
top20_ss['length_km'].plot.hist()
plt.xlim(15000, 31000)

# %%
plt.figure(figsize = (3, 2))
gdfns2[gdfns2.rmse < 2500]['length_km'].plot.hist()
top20_ns['length_km'].plot.hist()
plt.xlim(15000, 31000)

# %%
plt.figure(figsize = (3, 2))
gdfsa_am2[gdfsa_am2.rmse < 4000]['length_km'].plot.hist()
top20_sa_am['length_km'].plot.hist()
plt.xlim(15000, 31000)

# %%
plt.figure(figsize = (3, 2))
gdfsa_af2[gdfsa_af2.rmse < 4000]['length_km'].plot.hist()
top20_sa_af['length_km'].plot.hist()
plt.xlim(15000, 31000)

# %%
plt.figure(figsize = (3, 2))
gdfna2['length_km'].plot.hist()
top20_na['length_km'].plot.hist()
plt.xlim(15000, 31000)

# %%
print(top20_ss.rmse.mean(), top20_ns.rmse.mean(), top20_sa_am.rmse.mean(), top20_sa_af.rmse.mean(), top20_na.rmse.mean())

# %%
gdfss2[gdfss2.rmse < 2500].rmse.min()

# %%
gdfss2[gdfss2.rmse < 2500].rmse.std()

# %%
gdfss2f = gdfss2[gdfss2.rmse < 2500]
gdfns2f = gdfns2[gdfns2.rmse < 2500]
gdfsa_am2f = gdfsa_am2[gdfsa_am2.rmse < 2500]
gdfsa_af2f = gdfsa_af2[gdfsa_af2.rmse < 2500]
gdfna2f = gdfna2[gdfna2.rmse < 2500]

# %%
gdfss2f['z_min'] = (gdfss2f.rmse - gdfss2f.rmse.min())/gdfss2f.rmse.std()
gdfns2f['z_min'] = (gdfns2f.rmse - gdfns2f.rmse.min())/gdfns2f.rmse.std()
gdfsa_am2f['z_min'] = (gdfsa_am2f.rmse - gdfsa_am2f.rmse.min())/gdfsa_am2f.rmse.std()
gdfsa_af2f['z_min'] = (gdfsa_af2f.rmse - gdfsa_af2f.rmse.min())/gdfsa_af2f.rmse.std()
gdfna2f['z_min'] = (gdfna2f.rmse - gdfna2f.rmse.min())/gdfna2f.rmse.std()

# %%
z = 1
print(len(gdfss2f[gdfss2f.z_min <= z]),
     len(gdfns2f[gdfns2f.z_min <= z]),
     len(gdfsa_am2f[gdfsa_am2f.z_min <= z]),
     len(gdfsa_af2f[gdfsa_af2f.z_min <= z]),
     len(gdfna2f[gdfna2f.z_min <= z]),)

# %%
z = 1
print(len(gdfss2f[gdfss2f.z_min <= z])/195,
     len(gdfns2f[gdfns2f.z_min <= z])/195,
     len(gdfsa_am2f[gdfsa_am2f.z_min <= z])/195,
     len(gdfsa_af2f[gdfsa_af2f.z_min <= z])/195,
     len(gdfna2f[gdfna2f.z_min <= z])/195)

# %%
gdfss2f.z_min.plot.hist(bins = 50)
gdfns2f.z_min.plot.hist(alpha = 0.5, bins = 50)

# %%
gdfsa_am2f.z_min.plot.hist(bins = 50)
gdfsa_af2f.z_min.plot.hist(bins = 50, alpha = 0.5)
gdfna2f.z_min.plot.hist(alpha = 0.5, bins = 50)

# %%
gdfss2[gdfss2.rmse < 2500].rmse.plot.hist(bins = 50)
gdfns2[gdfns2.rmse < 2500].rmse.plot.hist(alpha = 0.5, bins = 50)

# %%
gdfsa_am2[gdfsa_am2.rmse < 2500].rmse.plot.hist(bins = 50)
gdfsa_af2[gdfsa_af2.rmse < 2500].rmse.plot.hist(bins = 50, alpha = 0.5)
gdfna2[gdfna2.rmse < 2500].rmse.plot.hist(alpha = 0.5, bins = 50)
